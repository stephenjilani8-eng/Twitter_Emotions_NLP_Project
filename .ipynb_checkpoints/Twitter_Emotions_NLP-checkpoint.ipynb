# %% [markdown]
# **BUILDING A MODEL TO RATE SENTIMENTS OF TWEETS ABOUT GOOGLE AND APPLE PRODUCTS**
# Student Name: Stephen Jilani Project: Phase 3 Date:14 June 2026

# %% [markdown]
# **1. BUSINESS UNDERSTANDING**

# %% [markdown]
# A Kenyan business man is in a predicament on whether to venture in Apple or Google products for their business. The businessman has an objective to build a classification model that will help them identify either to venture into either Apple or Google products.
#
# **STAKEHOLDERS**
#
# The stakeholder of the project is the Kenyan businessman at large, however, the specific persons of interest are his team which include the following:
#
#     1. Product managers
#     2. Sales and marketing department
#     3. Research and development department
#
# **BUSINESS OBJECTIVES** The primary objective is to build a classification model on twitter reviews on Google and Apple products to see if there are any patterns for which products the business can venture into.
#
#     1.
#     2.
#     3.
#
# **BUSINESS QUESTIONS**
#
#     1.
#     2.
#     3.

# %% [markdown]
# **2. DATA UNDERSTANDING**
